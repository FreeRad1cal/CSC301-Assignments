# %%
import numpy as np
import scipy.interpolate as interpolate
import scipy.fftpack as fft
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import gridplot
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="04300f5b-d444-4550-a49e-035d8a2b618f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="04300f5b-d444-4550-a49e-035d8a2b618f">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Problem 1

# %%
d = np.arange(30, 76, 5)
i = [0.85, 0.67, 0.52, 0.42, 0.34, 0.28, 0.24, 0.21, 0.18, 0.15]

# %%
def polynomial_fit(x, y, deg=None):
    if deg is None:
        deg = len(x) - 1
    p = np.polyfit(x, y, deg)
    return np.poly1d(p)

quad = polynomial_fit(d, i, 2)

# %%
def exp(x, y):
    log = interpolate.interp1d(x, np.log2(y), "linear")
    return np.vectorize(lambda val: 2**log(val))

exp = exp(d, i)

# %%
poly = polynomial_fit(d, i)

# %%
spline = interpolate.CubicSpline(d, i)

# %%
x = np.linspace(30, 75, 1000)
ys = [interpolator(x) for interpolator in (quad, exp, poly, spline)]

# %%
def make_figures(x, ys, fig_title, titles, colors):
    fig = figure(width=400, plot_height=400, title=fig_title)
    for y, title, color in zip(ys, titles, colors):
        fig.line(x, y, legend=title, line_color=color)
    return fig

# %%
figs = make_figures(x, ys, "Interpolating functions", 
                    ["quadratic", "exponential", "polynomial", "cubic spline"], 
                    ["red", "blue", "green", "orange"])

# %%
show(figs)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3cd796c3-63d1-4934-aedf-3c6729af18b1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("3cd796c3-63d1-4934-aedf-3c6729af18b1").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3cd796c3-63d1-4934-aedf-3c6729af18b1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3cd796c3-63d1-4934-aedf-3c6729af18b1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7a317655-c70d-4ec1-82f4-10eef2aad74d":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"3f6c3ade-54cf-4a91-aaad-d969c86593e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"f6c376fe-0510-4ef7-8cf8-afb392741c0c","type":"BasicTicker"}},"id":"0e966c2a-dffe-487f-9931-e69b4e16a099","type":"Grid"},{"attributes":{"callback":null},"id":"db939c5e-a72b-4e5e-89e4-ccc44e379750","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8d7976d5-582b-4a9b-a624-26cfa227af8e","type":"BoxAnnotation"},{"attributes":{},"id":"e25d3664-a35d-4bec-b4a1-eacd622aca90","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"72e28dbe-dc90-4f45-9024-9d0cbcb59de6","type":"ColumnDataSource"},{"attributes":{},"id":"f6c376fe-0510-4ef7-8cf8-afb392741c0c","type":"BasicTicker"},{"attributes":{"formatter":{"id":"d31184e3-7adf-4c0e-892f-1e2c5c84abe7","type":"BasicTickFormatter"},"plot":{"id":"3f6c3ade-54cf-4a91-aaad-d969c86593e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"f6c376fe-0510-4ef7-8cf8-afb392741c0c","type":"BasicTicker"}},"id":"f1d2a068-c239-40bc-8a62-e6dab3c2166d","type":"LinearAxis"},{"attributes":{"plot":{"id":"3f6c3ade-54cf-4a91-aaad-d969c86593e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"e25d3664-a35d-4bec-b4a1-eacd622aca90","type":"BasicTicker"}},"id":"c7187b35-3db6-40be-bd9b-30d73a32eabc","type":"Grid"},{"attributes":{"below":[{"id":"fb7fab40-587c-4b71-b983-219c85566b05","type":"LinearAxis"}],"left":[{"id":"f1d2a068-c239-40bc-8a62-e6dab3c2166d","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"fb7fab40-587c-4b71-b983-219c85566b05","type":"LinearAxis"},{"id":"c7187b35-3db6-40be-bd9b-30d73a32eabc","type":"Grid"},{"id":"f1d2a068-c239-40bc-8a62-e6dab3c2166d","type":"LinearAxis"},{"id":"0e966c2a-dffe-487f-9931-e69b4e16a099","type":"Grid"},{"id":"8d7976d5-582b-4a9b-a624-26cfa227af8e","type":"BoxAnnotation"},{"id":"75efdf89-dcab-4c0c-9481-008bc8592f21","type":"Legend"},{"id":"db57a877-900f-4dd6-8cf2-0a2c488f7d58","type":"GlyphRenderer"},{"id":"5b9963c1-c7a5-4d20-8f3f-161b270229cd","type":"GlyphRenderer"},{"id":"7955a4e5-1883-4a20-8ecd-fd0e2e0c1fa1","type":"GlyphRenderer"},{"id":"32916491-59eb-4e09-8aa9-3af1b7fd1cba","type":"GlyphRenderer"}],"title":{"id":"1c21a06b-d46e-42d1-a00e-ad9573f86e92","type":"Title"},"tool_events":{"id":"437f1ee5-25e2-484b-bf64-3c714ba9e229","type":"ToolEvents"},"toolbar":{"id":"444ff32a-99c3-4c27-ac1d-559c66a381e1","type":"Toolbar"},"x_range":{"id":"db939c5e-a72b-4e5e-89e4-ccc44e379750","type":"DataRange1d"},"y_range":{"id":"311119e8-c33f-471d-86fc-5c0b745060fa","type":"DataRange1d"}},"id":"3f6c3ade-54cf-4a91-aaad-d969c86593e0","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"437f1ee5-25e2-484b-bf64-3c714ba9e229","type":"ToolEvents"},{"attributes":{"formatter":{"id":"917eb5af-118d-403f-b5a5-1f8f46fcff2a","type":"BasicTickFormatter"},"plot":{"id":"3f6c3ade-54cf-4a91-aaad-d969c86593e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"e25d3664-a35d-4bec-b4a1-eacd622aca90","type":"BasicTicker"}},"id":"fb7fab40-587c-4b71-b983-219c85566b05","type":"LinearAxis"},{"attributes":{"callback":null},"id":"311119e8-c33f-471d-86fc-5c0b745060fa","type":"DataRange1d"},{"attributes":{"plot":null,"text":"Interpolating functions"},"id":"1c21a06b-d46e-42d1-a00e-ad9573f86e92","type":"Title"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"872bb008-f4e2-4bcd-bad4-dd739b3c361f","type":"Line"},{"attributes":{"label":{"value":"quadratic"},"renderers":[{"id":"db57a877-900f-4dd6-8 ...

# %% [markdown]
# ### Problem 2

# %%
def trig_interp(func, n=17):
    x_interp = np.arange(0, n+1)*(2*np.pi/n)
    coeffs = fft.fft(func(x_interp))/n
    def interpolator(x):
        y = np.zeros(len(x))
        for k in range(1, int((n+1)/2)):
            y = y + coeffs[k]*np.exp(1j*(k-1)*x)
        for k in range(int((n+1)/2+1), n):
            y = y + coeffs[k]*np.exp(1j*(-n+k-1)*x)
        return np.real(y)
    return interpolator
