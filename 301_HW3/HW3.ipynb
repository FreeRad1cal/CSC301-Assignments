# %%
import numpy as np
from scipy.interpolate import CubicSpline, KroghInterpolator, BarycentricInterpolator
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import gridplot
output_notebook()
import requests
import bs4
import re
import pandas as pd
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="497dbc78-a12b-4afa-8eab-0c08b1711203">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="497dbc78-a12b-4afa-8eab-0c08b1711203">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Problem #1

# %%
x = [16, 12, 6, 2, 4, 7, 11, 15, 14, 7]
y = [4, 1, 0, 4, 10, 15, 18, 17, 12, 8]

# %%
def spline_interpolation(x, y, bc, num_points):
    assert(len(x) == len(y))
    cs_x, cs_y = [CubicSpline(range(0, len(arr)), arr, bc_type=bc) for arr in (x, y)]
    return [cs(np.linspace(0, len(x), num_points)) for cs in (cs_x, cs_y)]

# %%
boundary_conditions = ["not-a-knot", "clamped", "natural", ((2,1),(2,1)), ((2,2),(2,1)), ((2,1),(2,2))]
spline_interpolations = [spline_interpolation(x, y, bc, 100) for bc in boundary_conditions]

# %%
def make_figure(x, y, title):
    if (isinstance(title, tuple)):
        muL, muR = list(zip(*title))[1]
        title = f"muL={muL}, muR={muR}"
    fig = figure(width=250, plot_height=250, title=title)
    fig.line(x, y)
    return fig

figs = [make_figure(tup[0], tup[1], title) for tup, title in zip(spline_interpolations, boundary_conditions)]
fig = gridplot(np.reshape(figs, (2, 3)).tolist())
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cac23d5a-d6ca-493e-95e5-7764e4ff605a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("cac23d5a-d6ca-493e-95e5-7764e4ff605a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cac23d5a-d6ca-493e-95e5-7764e4ff605a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cac23d5a-d6ca-493e-95e5-7764e4ff605a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f5c29956-6391-4851-bb20-7dad6ce9ab3e":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"c543607e-2bb8-4485-a714-d7c7e26e8a58","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"a2d6992d-e01d-4a1c-9391-d6abe9c9bb6e","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"73cc6f3e-613d-4fff-b83c-f6e9a71e2f3b","subtype":"Figure","type":"Plot"},"ticker":{"id":"92d43c4e-8f69-4965-b09a-3f16b2b94313","type":"BasicTicker"}},"id":"84c657df-130c-459b-9d5c-4e2f4e8ec92b","type":"Grid"},{"attributes":{"plot":{"id":"d3bffb70-ff36-4bbd-9880-0bbc4e0ef3ee","subtype":"Figure","type":"Plot"}},"id":"5872ebc0-38ef-4536-90ec-f66815ace076","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"33d8b22b-af47-422e-b0e6-7cba766d00a0","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"56cd75ca-9115-4280-98fd-b07a82fc96d9","type":"LinearAxis"}],"left":[{"id":"70dcd5b6-61ed-474e-937b-462f2ad84aac","type":"LinearAxis"}],"plot_height":250,"plot_width":250,"renderers":[{"id":"56cd75ca-9115-4280-98fd-b07a82fc96d9","type":"LinearAxis"},{"id":"d2fb1df9-784c-49cf-9d7c-d0cc3abc51bf","type":"Grid"},{"id":"70dcd5b6-61ed-474e-937b-462f2ad84aac","type":"LinearAxis"},{"id":"414d9f7e-ea2d-4a3b-9fa1-40ec70677fa9","type":"Grid"},{"id":"bc36f5c9-a071-42e3-b120-0f26894ec2c4","type":"BoxAnnotation"},{"id":"a3fb3e23-a10d-492c-8c1d-f98f801ac267","type":"GlyphRenderer"}],"title":{"id":"1b2a88b9-8a08-4b8a-828e-ab1b587a1256","type":"Title"},"tool_events":{"id":"9f72512a-203d-408f-9535-667c9c207c33","type":"ToolEvents"},"toolbar":{"id":"b86c2dfa-5e11-4bfa-929e-8123d409b651","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"a2d6992d-e01d-4a1c-9391-d6abe9c9bb6e","type":"DataRange1d"},"y_range":{"id":"dbd3ca94-7e18-4d5c-8395-002962f6d977","type":"DataRange1d"}},"id":"797b3652-b8f3-49d8-af9e-046e2eb605bb","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"d3bffb70-ff36-4bbd-9880-0bbc4e0ef3ee","subtype":"Figure","type":"Plot"}},"id":"1fb09687-b300-4f14-a667-237eb47d2730","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"33d8b22b-af47-422e-b0e6-7cba766d00a0","type":"BoxAnnotation"},"plot":{"id":"d3bffb70-ff36-4bbd-9880-0bbc4e0ef3ee","subtype":"Figure","type":"Plot"}},"id":"192cdf54-3264-4187-b609-a3bda5e156d2","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"d3bffb70-ff36-4bbd-9880-0bbc4e0ef3ee","subtype":"Figure","type":"Plot"}},"id":"99973c9e-6223-40c3-b9b2-a0a016483b0f","type":"PanTool"},{"attributes":{},"id":"b6f702be-0056-4231-b374-f0a8cf29c709","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d3bffb70-ff36-4bbd-9880-0bbc4e0ef3ee","subtype":"Figure","type":"Plot"}},"id":"75cb881e-d216-47ea-8c29-a0c5f13f68cc","type":"SaveTool"},{"attributes":{"plot":null,"text":"muL=1, muR=2"},"id":"1b2a88b9-8a08-4b8a-828e-ab1b587a1256","type":"Title"},{"attributes":{"plot":{"id":"d3bffb70-ff36-4bbd-9880-0bbc4e0ef3ee","subtype":"Figure","type":"Plot"}},"id":"49c29f1b-2802-4337-92d0-79887daec402","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"8956095b-2a20-41fd-b2f3-ec60fcbb985e","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9ed53dd5-e944-4ca8-8260-96fe58d0dd5c","type":"PanTool"},{"id":"798c9031-dc9a-48e2-9060-f11f5f6ca2b2","type":"WheelZoomTool"},{"id":"42afbb0b-41dc-4a6c-abc9-802f0f0f99a2","type":"BoxZoomTool"},{"id":"9d989749-a3 ...
#             var render_items = [{"docid":"f5c29956-6391-4851-bb20-7dad6ce9ab3e","elementid":"cac23d5a-d6ca-493e-95e5-7764e4ff605a","modelid":"b297b4b8-d345-4886-b1be-97cde8e70f81"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("cac23d5a-d6ca-493e-95e5-7764e4ff605a")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>

# %% [markdown]
# ### Problem 2

# %%
url = "https://en.wikipedia.org/wiki/History_of_United_States_postage_rates"
source = requests.get(url).content
bs_tree = bs4.BeautifulSoup(source, "lxml")
rows = bs_tree.find("table").findAll("tr")

# %%
years_and_prices = [row.findAll("td")[0:2] for row in rows[1:]]
years_and_prices = [(re.search(r"\d{4}", year.text).group(), re.match(r".\d+", price.text).group()) for year, price in years_and_prices]
years_and_prices = [(int(year), float(price)) for year, price in years_and_prices]
years_and_prices = {price: year for year, price in sorted(years_and_prices, key=lambda tup: tup[1])}

# %%
prices, years = zip(*years_and_prices.items())

# %%
def coef(x, y):
    np.array(x).astype(float)
    np.array(y).astype(float)
    n = len(x)
    a = []
    for i in range(n):
        a.append(y[i])

    for j in range(1, n):
        for i in range(n-1, j-1, -1):
            a[i] = float(a[i]-a[i-1])/float(x[i]-x[i-j])
    return np.array(a)

# %%
titles = ["cubic spline", "newton polynomial", "least squares polynomial"]
spline = CubicSpline(prices, years, bc_type="not-a-knot")
newton_poly = np.poly1d(coef(prices, years))
least_squares_poly = np.poly1d(np.polyfit(prices, years, 5))
df = pd.DataFrame(index=titles, columns=["year when cost = 0.5"])
df.iloc[:,0] = [spline(0.5), newton_poly(0.5), least_squares_poly(0.5)]
df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>year when cost = 0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>cubic spline</th>
#       <td>2007.5835955360908</td>
#     </tr>
#     <tr>
#       <th>newton polynomial</th>
#       <td>2.45567e+23</td>
#     </tr>
#     <tr>
#       <th>least squares polynomial</th>
#       <td>2022.77</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
x = np.linspace(0, 0.51, 1000)
ys = [spline(x), newton_poly(x), least_squares_poly(x)]

# %%
def make_figure(x, y, title):
    fig = figure(width=250, plot_height=250, title=title)
    fig.line(x, y)
    return fig

plots = [make_figure(x, y, title) for y, title in zip(ys, titles)]
fig = gridplot([plots])
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="98414ddf-b37d-4cfd-9b64-0d7524122857"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("98414ddf-b37d-4cfd-9b64-0d7524122857").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("98414ddf-b37d-4cfd-9b64-0d7524122857");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '98414ddf-b37d-4cfd-9b64-0d7524122857' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"499e5267-30f8-4f4f-829c-0c056cc7b22d":{"roots":{"references":[{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"745e211f-eddf-470e-9c11-31347463b03b","type":"Line"},{"attributes":{"plot":{"id":"990be557-99c9-419b-8023-bb67619fafac","subtype":"Figure","type":"Plot"}},"id":"533d1458-15aa-4b5d-904c-510c0668a921","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"17faca31-70f7-4348-8138-02d845539150","type":"LinearAxis"}],"left":[{"id":"695a4c2c-a850-457c-95b4-5bd95a00d9ee","type":"LinearAxis"}],"plot_height":250,"plot_width":250,"renderers":[{"id":"17faca31-70f7-4348-8138-02d845539150","type":"LinearAxis"},{"id":"6776b432-eb45-49da-aee9-4bfcd1ae60b0","type":"Grid"},{"id":"695a4c2c-a850-457c-95b4-5bd95a00d9ee","type":"LinearAxis"},{"id":"54fd0193-6392-4463-920c-4e4f8678d511","type":"Grid"},{"id":"acac2e3b-24d2-433a-b4f4-09747c60570f","type":"BoxAnnotation"},{"id":"1f68ce3a-fa10-4d17-80ea-b1b5855c07a0","type":"GlyphRenderer"}],"title":{"id":"8f911138-7ac0-47e5-a09a-40d2da09c5de","type":"Title"},"tool_events":{"id":"587a733a-f462-467d-bb3d-7876d97a0022","type":"ToolEvents"},"toolbar":{"id":"94abef98-fdfa-47ff-a17b-901bd5392791","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"f0b431e1-6754-4178-98b8-9c55e46a8dca","type":"DataRange1d"},"y_range":{"id":"28a972cc-7035-4123-8c3a-1b501a86f5c0","type":"DataRange1d"}},"id":"990be557-99c9-419b-8023-bb67619fafac","subtype":"Figure","type":"Plot"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d9b89180-f570-4119-a048-2340ab2245bb","type":"Line"},{"attributes":{"plot":{"id":"990be557-99c9-419b-8023-bb67619fafac","subtype":"Figure","type":"Plot"}},"id":"a84902e2-3f7f-434d-9c12-904bdb8b0fa7","type":"PanTool"},{"attributes":{"plot":null,"text":"cubic spline"},"id":"8f911138-7ac0-47e5-a09a-40d2da09c5de","type":"Title"},{"attributes":{"plot":{"id":"990be557-99c9-419b-8023-bb67619fafac","subtype":"Figure","type":"Plot"}},"id":"6e4f567c-0c78-496d-b069-20c392b7c487","type":"HelpTool"},{"attributes":{},"id":"587a733a-f462-467d-bb3d-7876d97a0022","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"990be557-99c9-419b-8023-bb67619fafac","subtype":"Figure","type":"Plot"},"ticker":{"id":"acb38b58-9335-4ef7-8502-6dd4ecad1409","type":"BasicTicker"}},"id":"54fd0193-6392-4463-920c-4e4f8678d511","type":"Grid"},{"attributes":{"formatter":{"id":"148b6e5a-24a3-494b-80cc-8b70f0d62ad2","type":"BasicTickFormatter"},"plot":{"id":"990be557-99c9-419b-8023-bb67619fafac","subtype":"Figure","type":"Plot"},"ticker":{"id":"acb38b58-9335-4ef7-8502-6dd4ecad1409","type":"BasicTicker"}},"id":"695a4c2c-a850-457c-95b4-5bd95a00d9ee","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"d49e1499-f0fe-4fbd-b33c-c316dc02b143","type":"ColumnDataSource"},{"attributes":{},"id":"148b6e5a-24a3-494b-80cc-8b70f0d62ad2","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"990be557-99c9-419b-8023-bb67619fafac","subtype":"Figure","type":"Plot"},"ticker":{"id":"fedf625d-234f-4e61-8a30-b5092e67138b","type":"BasicTicker"}},"id":"6776b432-eb45-49da-aee9-4bfcd1ae60b0","type":"Grid"},{"attributes":{},"id":"fedf625d-234f-4e61-8a30-b5092e67138b","type":"BasicTicker"},{"attributes":{"children":[{"id":"9a9d6305-4d85-453a-bc4b-4e938844232b","type":"Row"}]},"id":"7dbb4b5f-1244-405e-a580-0634714d1b76","type":"Column"},{"attributes":{"below":[{"id":"d2037bf9-c375-4e65-a06b-399351ccf356","type":"LinearAxis"}],"left":[{"id":"1875dc34-3c5c-470b-b5a3-1dc98e75f851","type":"LinearAxis"}],"plot_height":250,"plot_width":250,"renderers":[{"id":"d2037bf9-c375-4e65-a06b-399351ccf356","type":"LinearAxis"},{"id":"3211763f-d9df-4314-bad6-caa0c0ce97d6","type":"Grid"},{"id":"1875dc34-3c5c-470b-b5a3-1dc98e75f851","type":"LinearAxis"},{"id":"86500497-04 ...
#             var render_items = [{"docid":"499e5267-30f8-4f4f-829c-0c056cc7b22d","elementid":"98414ddf-b37d-4cfd-9b64-0d7524122857","modelid":"fdcf1db0-29fb-4332-9660-950ddc4fa9eb"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("98414ddf-b37d-4cfd-9b64-0d7524122857")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>

# %% [markdown]
# ### Problem #3

# %%
url = "https://en.wikipedia.org/wiki/United_States_Census"
source = requests.get(url).content
bs_tree = bs4.BeautifulSoup(source, "lxml")
rows = bs_tree.findAll("table")[1].findAll("tr")[1:]

# %%
def choose_indexes(arr, indexes):
    return [arr[i] for i in indexes]

years_and_populations = [choose_indexes(row.findAll("td"), [1,3]) for row in rows]
years_and_populations = [(int(year.text), int(population.text.replace(",",""))) for year, population in years_and_populations]
years_and_populations
# Out:
# [(1790, 3929326),
#  (1800, 5308483),
#  (1810, 7239881),
#  (1820, 9638453),
#  (1830, 12866020),
#  (1840, 17069453),
#  (1850, 23191876),
#  (1860, 31443321),
#  (1870, 39818449),
#  (1880, 50189209),
#  (1890, 62947714),
#  (1900, 76212168),
#  (1910, 92228496),
#  (1920, 106021537),
#  (1930, 122775046),
#  (1940, 132164569),
#  (1950, 150697361),
#  (1960, 179323175),
#  (1970, 203302031),
#  (1980, 226545805),
#  (1990, 248709873),
#  (2000, 281421906),
#  (2010, 308745538)]

# %%
years, populations = zip(*years_and_populations)
spline = CubicSpline(years, populations, bc_type="natural")

# %%
x = np.arange(np.min(years), np.max(years)+1)
y = spline(x)

# %%
plot = figure(width=350, plot_height=350, title="United States Census")
plot.line(x, y)
pass

# %%
def compute_error(x, y, index):
    x_arr, y_arr = np.array(x), np.array(y)
    assert(x_arr.shape == y_arr.shape)
    mask = np.ones(len(x),dtype=bool)
    mask[index] = 0
    spline = CubicSpline(x_arr[mask], y_arr[mask], bc_type="natural")
    validation_sample = spline(x_arr[index])
    return np.abs((y[index] - validation_sample)/y[index])

errors = [compute_error(years, populations, i) for i in range(0, len(years))]

# %%
error_plot = figure(width=350, plot_height=350, title="Interpolation error")
error_plot.line(years, errors)
show(gridplot([[plot, error_plot]]))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e4c959cb-cdd9-437e-ac5a-ac300cdf96ef"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e4c959cb-cdd9-437e-ac5a-ac300cdf96ef").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e4c959cb-cdd9-437e-ac5a-ac300cdf96ef");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e4c959cb-cdd9-437e-ac5a-ac300cdf96ef' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d50e3285-4655-4260-a4fe-f17f81fcb80c":{"roots":{"references":[{"attributes":{"below":[{"id":"eb5fb221-f74c-4341-8afb-22d727c00e1c","type":"LinearAxis"}],"left":[{"id":"a31c9a8b-1f11-4c2b-8ced-ca4b5aebb593","type":"LinearAxis"}],"plot_height":350,"plot_width":350,"renderers":[{"id":"eb5fb221-f74c-4341-8afb-22d727c00e1c","type":"LinearAxis"},{"id":"52f059a1-541b-46de-83a0-59db5818c1ab","type":"Grid"},{"id":"a31c9a8b-1f11-4c2b-8ced-ca4b5aebb593","type":"LinearAxis"},{"id":"0d87636e-d6aa-4ba3-9164-680f94662865","type":"Grid"},{"id":"9474ee22-7df7-4188-bf8c-3780f7a906c4","type":"BoxAnnotation"},{"id":"d41640f8-7166-4b3b-b45f-74c8cddc2389","type":"GlyphRenderer"}],"title":{"id":"d384fad1-eb91-4546-afad-902b5d94c9eb","type":"Title"},"tool_events":{"id":"6d40db6c-3213-4fc4-94e4-1f4682099d7d","type":"ToolEvents"},"toolbar":{"id":"ba4255ab-ab27-447a-b2f1-b85776cc7a0f","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"5d436d77-137f-42b6-bc37-4c3787cb4d19","type":"DataRange1d"},"y_range":{"id":"b1a1672f-5b95-4993-b2c1-b6d106816ef0","type":"DataRange1d"}},"id":"8cdea8dc-5e67-4dfd-9ca7-3523473a7faa","subtype":"Figure","type":"Plot"},{"attributes":{"below":[{"id":"c50d6098-0bc1-46f4-b90b-1484abde6d8e","type":"LinearAxis"}],"left":[{"id":"ab8e866e-8596-4255-98c4-1ce760663c10","type":"LinearAxis"}],"plot_height":350,"plot_width":350,"renderers":[{"id":"c50d6098-0bc1-46f4-b90b-1484abde6d8e","type":"LinearAxis"},{"id":"93b63565-cc16-41ec-b14e-de38330edd94","type":"Grid"},{"id":"ab8e866e-8596-4255-98c4-1ce760663c10","type":"LinearAxis"},{"id":"5c46fdc9-39e1-4f8a-9891-c60678b74b65","type":"Grid"},{"id":"e91a5147-27eb-4ca7-8a29-60e843527f4c","type":"BoxAnnotation"},{"id":"251563e4-3c1e-44c4-9be2-c2a12c7f34e0","type":"GlyphRenderer"}],"title":{"id":"28539bc6-a78d-41a7-9bf3-b7b4bf029bab","type":"Title"},"tool_events":{"id":"4460c611-461f-4290-b92b-4d86d80dd362","type":"ToolEvents"},"toolbar":{"id":"ce342c16-c795-4a1f-a9f5-1201e3e3be1d","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"a49ad979-cc96-4a1c-975b-2dc0782f34c7","type":"DataRange1d"},"y_range":{"id":"4cd7b777-4044-408c-8d3a-411854ba36f2","type":"DataRange1d"}},"id":"78c7f74a-51eb-4c94-8fc4-9d2c615b2d28","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"United States Census"},"id":"d384fad1-eb91-4546-afad-902b5d94c9eb","type":"Title"},{"attributes":{"plot":null,"text":"Interpolation error"},"id":"28539bc6-a78d-41a7-9bf3-b7b4bf029bab","type":"Title"},{"attributes":{"callback":null},"id":"a49ad979-cc96-4a1c-975b-2dc0782f34c7","type":"DataRange1d"},{"attributes":{},"id":"4460c611-461f-4290-b92b-4d86d80dd362","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a49fe606-a482-42a1-9365-a3fc5261fbc9","type":"PanTool"},{"id":"d0c4407f-cddb-4291-827f-7b7fdf3a786c","type":"WheelZoomTool"},{"id":"1e7b9daa-36cb-4635-9222-7db82d78b7e8","type":"BoxZoomTool"},{"id":"4cc599e2-7d8d-47f3-b981-f0c7a74e53b2","type":"SaveTool"},{"id":"d2c400c6-e9e2-449f-a27b-1661734b955f","type":"ResetTool"},{"id":"586e0990-a28d-4254-bcd7-2ba885645f61","type":"HelpTool"}]},"id":"ce342c16-c795-4a1f-a9f5-1201e3e3be1d","type":"Toolbar"},{"attributes":{"formatter":{"id":"df68f945-3e11-4cf1-954f-b33bb50789c1","type":"BasicTickFormatter"},"plot":{"id":"78c7f74a-51eb-4c94-8fc4-9d2c615b2d28","subtype":"Figure","type":"Plot"},"ticker":{"id":"689c3f46-3ade-4d45-92e2-44f59d29e1e8","type":"BasicTicker"}},"id":"c50d6098-0bc1-46f4-b90b-1484abde6d8e","type":"LinearAxis"},{"attributes":{"callback":null},"id":"4cd7b777-4044-408c-8d3a-411854ba36f2","type":"DataRange1d"},{"attributes":{},"id":"689c3f46-3ade-4d45-92e2-44f59d29e1e8","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8b0cb084-e2a2-4522-a43f-86f6888b2066","type":"Line"},{"attributes":{"plot":{"id":"78c7f74a-51eb-4c94-8fc4-9d2c615b2d28","subtype":"Figure","type":"Plot"},"ticker":{"id":"689c3f46-3 ...
#             var render_items = [{"docid":"d50e3285-4655-4260-a4fe-f17f81fcb80c","elementid":"e4c959cb-cdd9-437e-ac5a-ac300cdf96ef","modelid":"2ecfb4e7-62d7-48d7-aed6-2b29787902d4"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("e4c959cb-cdd9-437e-ac5a-ac300cdf96ef")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>

# %% [markdown]
# The error is higher at the beginning endpoint but is overall quite low.
